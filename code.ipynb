# %%
import IPython
url = 'https://www.pythonanywhere.com/embedded3/'
iframe = ''
IPython.display.HTML(iframe)

# %%
print("Hello, world!")
help(print)

# %%
PI = 3.14
PI
print("PI =",PI)
help(print)
